# %%
import random
import time


class PercentageWeightedWheel:
    def __init__(self, starting_points=100, starting_spins=5, verbose=True):
        self.points = starting_points
        self.highest_points = starting_points
        self.free_spins = starting_spins
        self.verbose = verbose
        self.total_spins_cast = 0

        self.wheel_outcomes = ["POINTS", "PERCENTAGE", "FREE_SPINS", "DOUBLE"]
        self.wheel_weights = [0.55, 0.20, 0.15, 0.10]

        self.points_list = [
            100,
            150,
            200,
            250,
            300,
            400,
            500,
            750,
            1000,
            1500,
            2000,
            2500,
            3000,
            4000,
            5000,
            7500,
            10000,
        ]
        self.points_weights = [
            0.20,
            0.16,
            0.14,
            0.12,
            0.10,
            0.08,
            0.06,
            0.04,
            0.03,
            0.02,
            0.015,
            0.01,
            0.008,
            0.006,
            0.005,
            0.004,
            0.002,
        ]

        self.percentage_list = [0.10, 0.20, 0.25, 0.50, 0.75, 1.00]
        self.percentage_weights = [0.34, 0.26, 0.18, 0.12, 0.07, 0.03]
        self.percentage_signs = [1, -1]
        self.percentage_sign_weights = [0.5, 0.5]

        self.spins_payout_list = [2, 3, 5]
        self.spins_payout_weights = [0.50, 0.30, 0.20]

    def roll_discrete_points(self):
        return random.choices(self.points_list, weights=self.points_weights, k=1)[0]

    def roll_percentage_change(self):
        magnitude = random.choices(
            self.percentage_list, weights=self.percentage_weights, k=1
        )[0]
        sign = random.choices(
            self.percentage_signs, weights=self.percentage_sign_weights, k=1
        )[0]
        return magnitude * sign

    def roll_nested_free_spins(self):
        return random.choices(
            self.spins_payout_list, weights=self.spins_payout_weights, k=1
        )[0]

    def spin(self):
        if self.free_spins <= 0:
            if self.verbose:
                print("\nOut of spins! Game Over.")
            return False

        self.free_spins -= 1
        self.total_spins_cast += 1
        landed_outcome = random.choices(
            self.wheel_outcomes, weights=self.wheel_weights, k=1
        )[0]

        if landed_outcome == "POINTS":
            points_won = self.roll_discrete_points()
            self.points += points_won
            message = f"Standard Points: +{points_won:,}"
        elif landed_outcome == "PERCENTAGE":
            percentage_change = self.roll_percentage_change()
            old_points = self.points
            self.points = max(0, round(self.points * (1 + percentage_change)))
            label = f"{percentage_change:+.0%}"
            message = (
                f"Percentage Change: {label} " f"({old_points:,} -> {self.points:,})"
            )
        elif landed_outcome == "FREE_SPINS":
            spins_won = self.roll_nested_free_spins()
            self.free_spins += spins_won
            message = f"Free Spins: +{spins_won}"
        else:
            old_points = self.points
            self.points *= 2
            message = f"Double Points: {old_points:,} -> {self.points:,}"

        self.highest_points = max(self.highest_points, self.points)
        if self.verbose:
            print(message)
            self.display_hud()
        return True

    def display_hud(self):
        print("-" * 70)
        print(
            f"POINTS TOTAL: {self.points:,}  | "
            f"HIGHEST: {self.highest_points:,}  | "
            f"REMAINING SPINS: {self.free_spins}"
        )
        print("-" * 70)


game = PercentageWeightedWheel(starting_points=100, starting_spins=5, verbose=True)
game.display_hud()
while game.spin():
    pass
print(
    f"Session Terminated: {game.points:,} points | "
    f"Highest Points: {game.highest_points:,} across "
    f"{game.total_spins_cast} casts."
)
# Out:
# ----------------------------------------------------------------------
# POINTS TOTAL: 100  | HIGHEST: 100  | REMAINING SPINS: 5
# ----------------------------------------------------------------------
# Free Spins: +5
# ----------------------------------------------------------------------
# POINTS TOTAL: 100  | HIGHEST: 100  | REMAINING SPINS: 9
# ----------------------------------------------------------------------
# Standard Points: +7,500
# ----------------------------------------------------------------------
# POINTS TOTAL: 7,600  | HIGHEST: 7,600  | REMAINING SPINS: 8
# ----------------------------------------------------------------------
# Percentage Change: -50% (7,600 -> 3,800)
# ----------------------------------------------------------------------
# POINTS TOTAL: 3,800  | HIGHEST: 7,600  | REMAINING SPINS: 7
# ----------------------------------------------------------------------
# Double Points: 3,800 -> 7,600
# ----------------------------------------------------------------------
# POINTS TOTAL: 7,600  | HIGHEST: 7,600  | REMAINING SPINS: 6
# ----------------------------------------------------------------------
# Standard Points: +200
# ----------------------------------------------------------------------
# POINTS TOTAL: 7,800  | HIGHEST: 7,800  | REMAINING SPINS: 5
# ----------------------------------------------------------------------
# Free Spins: +5
# ----------------------------------------------------------------------
# POINTS TOTAL: 7,800  | HIGHEST: 7,800  | REMAINING SPINS: 9
# ----------------------------------------------------------------------
# Standard Points: +100
# ----------------------------------------------------------------------
# POINTS TOTAL: 7,900  | HIGHEST: 7,900  | REMAINING SPINS: 8
# ----------------------------------------------------------------------
# Double Points: 7,900 -> 15,800
# ----------------------------------------------------------------------
# POINTS TOTAL: 15,800  | HIGHEST: 15,800  | REMAINING SPINS: 7
# ----------------------------------------------------------------------
# Standard Points: +400
# ----------------------------------------------------------------------
# POINTS TOTAL: 16,200  | HIGHEST: 16,200  | REMAINING SPINS: 6
# ----------------------------------------------------------------------
# Free Spins: +2
# ----------------------------------------------------------------------
# POINTS TOTAL: 16,200  | HIGHEST: 16,200  | REMAINING SPINS: 7
# ----------------------------------------------------------------------
# Standard Points: +400
# ----------------------------------------------------------------------
# POINTS TOTAL: 16,600  | HIGHEST: 16,600  | REMAINING SPINS: 6
# ----------------------------------------------------------------------
# Standard Points: +300
# ----------------------------------------------------------------------
# POINTS TOTAL: 16,900  | HIGHEST: 16,900  | REMAINING SPINS: 5
# ----------------------------------------------------------------------
# Free Spins: +2
# ----------------------------------------------------------------------
# POINTS TOTAL: 16,900  | HIGHEST: 16,900  | REMAINING SPINS: 6
# ----------------------------------------------------------------------
# Free Spins: +5
# ----------------------------------------------------------------------
# POINTS TOTAL: 16,900  | HIGHEST: 16,900  | REMAINING SPINS: 10
# ----------------------------------------------------------------------
# Double Points: 16,900 -> 33,800
# ----------------------------------------------------------------------
# POINTS TOTAL: 33,800  | HIGHEST: 33,800  | REMAINING SPINS: 9
# ----------------------------------------------------------------------
# Free Spins: +2
# ----------------------------------------------------------------------
# POINTS TOTAL: 33,800  | HIGHEST: 33,800  | REMAINING SPINS: 10
# ----------------------------------------------------------------------
# Standard Points: +1,000
# ----------------------------------------------------------------------
# POINTS TOTAL: 34,800  | HIGHEST: 34,800  | REMAINING SPINS: 9
# ----------------------------------------------------------------------
# Standard Points: +200
# ----------------------------------------------------------------------
# POINTS TOTAL: 35,000  | HIGHEST: 35,000  | REMAINING SPINS: 8
# ----------------------------------------------------------------------
# Standard Points: +250
# ----------------------------------------------------------------------
# POINTS TOTAL: 35,250  | HIGHEST: 35,250  | REMAINING SPINS: 7
# ----------------------------------------------------------------------
# Free Spins: +2
# ----------------------------------------------------------------------
# POINTS TOTAL: 35,250  | HIGHEST: 35,250  | REMAINING SPINS: 8
# ----------------------------------------------------------------------
# Standard Points: +200
# ----------------------------------------------------------------------
# POINTS TOTAL: 35,450  | HIGHEST: 35,450  | REMAINING SPINS: 7
# ----------------------------------------------------------------------
# Standard Points: +100
# ----------------------------------------------------------------------
# POINTS TOTAL: 35,550  | HIGHEST: 35,550  | REMAINING SPINS: 6
# ----------------------------------------------------------------------
# Standard Points: +100
# ----------------------------------------------------------------------
# POINTS TOTAL: 35,650  | HIGHEST: 35,650  | REMAINING SPINS: 5
# ----------------------------------------------------------------------
# Double Points: 35,650 -> 71,300
# ----------------------------------------------------------------------
# POINTS TOTAL: 71,300  | HIGHEST: 71,300  | REMAINING SPINS: 4
# ----------------------------------------------------------------------
# Standard Points: +300
# ----------------------------------------------------------------------
# POINTS TOTAL: 71,600  | HIGHEST: 71,600  | REMAINING SPINS: 3
# ----------------------------------------------------------------------
# Percentage Change: -10% (71,600 -> 64,440)
# ----------------------------------------------------------------------
# POINTS TOTAL: 64,440  | HIGHEST: 71,600  | REMAINING SPINS: 2
# ----------------------------------------------------------------------
# Standard Points: +250
# ----------------------------------------------------------------------
# POINTS TOTAL: 64,690  | HIGHEST: 71,600  | REMAINING SPINS: 1
# ----------------------------------------------------------------------
# Percentage Change: +20% (64,690 -> 77,628)
# ----------------------------------------------------------------------
# POINTS TOTAL: 77,628  | HIGHEST: 77,628  | REMAINING SPINS: 0
# ----------------------------------------------------------------------
#
# Out of spins! Game Over.
# Session Terminated: 77,628 points | Highest Points: 77,628 across 28 casts.

# %%
for _ in range(100):
    wheel = PercentageWeightedWheel(
        starting_points=100, starting_spins=5, verbose=False
    )
    while wheel.spin():
        pass
    print(
        f"Percentage Game over -> Points: {wheel.points:,} | "
        f"Highest Points: {wheel.highest_points:,} | "
        f"Total spins cast: {wheel.total_spins_cast}"
    )

    ten_spins = PercentageWeightedWheel(
        starting_points=100, starting_spins=10, verbose=False
    )
    while ten_spins.spin():
        pass
    print(
        f"Ten Spins Percentage Game over -> Points: {ten_spins.points:,} | "
        f"Highest Points: {ten_spins.highest_points:,} | "
        f"Total spins cast: {ten_spins.total_spins_cast}"
    )

    zero_points = PercentageWeightedWheel(
        starting_points=0, starting_spins=5, verbose=False
    )
    while zero_points.spin():
        pass
    print(
        f"Zero Points Percentage Game over -> Points: {zero_points.points:,} | "
        f"Highest Points: {zero_points.highest_points:,} | "
        f"Total spins cast: {zero_points.total_spins_cast}"
    )

    ten_spins_zero_points = PercentageWeightedWheel(
        starting_points=0, starting_spins=10, verbose=False
    )
    while ten_spins_zero_points.spin():
        pass
    print(
        f"Ten Spins Zero Points Percentage Game over -> Points: {ten_spins_zero_points.points:,} | "
        f"Highest Points: {ten_spins_zero_points.highest_points:,} | "
        f"Total spins cast: {ten_spins_zero_points.total_spins_cast}"
    )
# Out:
# Percentage Game over -> Points: 878 | Highest Points: 878 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 12,700 | Highest Points: 12,700 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 4,400 | Highest Points: 4,400 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 2,820 | Highest Points: 2,820 | Total spins cast: 10
# Percentage Game over -> Points: 1,475 | Highest Points: 1,475 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 1,976 | Highest Points: 9,206 | Total spins cast: 23
# Zero Points Percentage Game over -> Points: 16,100 | Highest Points: 16,100 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 8,138 | Highest Points: 8,138 | Total spins cast: 10
# Percentage Game over -> Points: 1,260 | Highest Points: 1,260 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 1,290 | Highest Points: 1,290 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 12,609 | Highest Points: 12,609 | Total spins cast: 35
# Ten Spins Zero Points Percentage Game over -> Points: 18,920 | Highest Points: 18,920 | Total spins cast: 18
# Percentage Game over -> Points: 722 | Highest Points: 722 | Total spins cast: 8
# Ten Spins Percentage Game over -> Points: 3,852 | Highest Points: 3,852 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 4,450 | Highest Points: 4,450 | Total spins cast: 12
# Ten Spins Zero Points Percentage Game over -> Points: 4,700 | Highest Points: 4,700 | Total spins cast: 13
# Percentage Game over -> Points: 2,650 | Highest Points: 3,000 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 13,500 | Highest Points: 13,500 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 6,200 | Highest Points: 6,200 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 10,025 | Highest Points: 10,025 | Total spins cast: 13
# Percentage Game over -> Points: 6,310 | Highest Points: 6,310 | Total spins cast: 14
# Ten Spins Percentage Game over -> Points: 12,746 | Highest Points: 12,746 | Total spins cast: 17
# Zero Points Percentage Game over -> Points: 700 | Highest Points: 700 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 0 | Highest Points: 5,040 | Total spins cast: 10
# Percentage Game over -> Points: 6,900 | Highest Points: 6,900 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 5,472 | Highest Points: 5,472 | Total spins cast: 18
# Zero Points Percentage Game over -> Points: 698 | Highest Points: 776 | Total spins cast: 8
# Ten Spins Zero Points Percentage Game over -> Points: 7,026 | Highest Points: 7,026 | Total spins cast: 23
# Percentage Game over -> Points: 3,100 | Highest Points: 3,100 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 10,080 | Highest Points: 10,080 | Total spins cast: 38
# Zero Points Percentage Game over -> Points: 9,856 | Highest Points: 12,320 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 2,225 | Highest Points: 2,225 | Total spins cast: 12
# Percentage Game over -> Points: 722 | Highest Points: 722 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 6,410 | Highest Points: 8,625 | Total spins cast: 18
# Zero Points Percentage Game over -> Points: 6,475 | Highest Points: 6,475 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 1,780 | Highest Points: 1,780 | Total spins cast: 13
# Percentage Game over -> Points: 3,760 | Highest Points: 3,900 | Total spins cast: 15
# Ten Spins Percentage Game over -> Points: 639 | Highest Points: 1,278 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 2,712 | Highest Points: 2,712 | Total spins cast: 8
# Ten Spins Zero Points Percentage Game over -> Points: 69,235 | Highest Points: 83,340 | Total spins cast: 49
# Percentage Game over -> Points: 2,925 | Highest Points: 2,925 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 5,878 | Highest Points: 21,808 | Total spins cast: 26
# Zero Points Percentage Game over -> Points: 5,475 | Highest Points: 5,475 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 20,200 | Highest Points: 20,200 | Total spins cast: 10
# Percentage Game over -> Points: 12,518 | Highest Points: 16,690 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 6,005 | Highest Points: 6,005 | Total spins cast: 22
# Zero Points Percentage Game over -> Points: 1,538 | Highest Points: 1,538 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 2,025 | Highest Points: 2,250 | Total spins cast: 10
# Percentage Game over -> Points: 5,920 | Highest Points: 5,920 | Total spins cast: 8
# Ten Spins Percentage Game over -> Points: 33,860 | Highest Points: 33,860 | Total spins cast: 22
# Zero Points Percentage Game over -> Points: 800 | Highest Points: 800 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 8,408 | Highest Points: 8,408 | Total spins cast: 10
# Percentage Game over -> Points: 1,750 | Highest Points: 1,750 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 3,578 | Highest Points: 3,578 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 2,950 | Highest Points: 2,950 | Total spins cast: 9
# Ten Spins Zero Points Percentage Game over -> Points: 11,696 | Highest Points: 11,696 | Total spins cast: 23
# Percentage Game over -> Points: 386 | Highest Points: 386 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 2,332 | Highest Points: 2,332 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 975 | Highest Points: 975 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 3,390 | Highest Points: 3,390 | Total spins cast: 13
# Percentage Game over -> Points: 6,870 | Highest Points: 6,870 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 5,520 | Highest Points: 5,520 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 17,734 | Highest Points: 19,704 | Total spins cast: 22
# Ten Spins Zero Points Percentage Game over -> Points: 2,500 | Highest Points: 2,500 | Total spins cast: 10
# Percentage Game over -> Points: 6,376 | Highest Points: 7,085 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 17,366 | Highest Points: 19,296 | Total spins cast: 21
# Zero Points Percentage Game over -> Points: 1,834 | Highest Points: 1,834 | Total spins cast: 14
# Ten Spins Zero Points Percentage Game over -> Points: 3,270 | Highest Points: 3,270 | Total spins cast: 15
# Percentage Game over -> Points: 1,880 | Highest Points: 1,880 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 7,561 | Highest Points: 7,561 | Total spins cast: 18
# Zero Points Percentage Game over -> Points: 442 | Highest Points: 442 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 9,542 | Highest Points: 9,542 | Total spins cast: 17
# Percentage Game over -> Points: 2,821 | Highest Points: 2,821 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 1,155 | Highest Points: 1,155 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 850 | Highest Points: 850 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 4,435 | Highest Points: 5,544 | Total spins cast: 15
# Percentage Game over -> Points: 850 | Highest Points: 850 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 4,173 | Highest Points: 4,173 | Total spins cast: 14
# Zero Points Percentage Game over -> Points: 26,700 | Highest Points: 26,700 | Total spins cast: 53
# Ten Spins Zero Points Percentage Game over -> Points: 7,998 | Highest Points: 7,998 | Total spins cast: 41
# Percentage Game over -> Points: 723 | Highest Points: 723 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 3,251 | Highest Points: 3,501 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 3,812 | Highest Points: 3,812 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 9,010 | Highest Points: 9,010 | Total spins cast: 12
# Percentage Game over -> Points: 2,450 | Highest Points: 2,450 | Total spins cast: 10
# Ten Spins Percentage Game over -> Points: 2,592 | Highest Points: 2,592 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 53,800 | Highest Points: 53,800 | Total spins cast: 23
# Ten Spins Zero Points Percentage Game over -> Points: 8,150 | Highest Points: 8,150 | Total spins cast: 15
# Percentage Game over -> Points: 1,510 | Highest Points: 1,510 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 5,569 | Highest Points: 5,569 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 4,152 | Highest Points: 4,152 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 6,094 | Highest Points: 12,312 | Total spins cast: 19
# Percentage Game over -> Points: 3,470 | Highest Points: 3,470 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 960 | Highest Points: 1,440 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 900 | Highest Points: 900 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 59,132 | Highest Points: 59,132 | Total spins cast: 23
# Percentage Game over -> Points: 464 | Highest Points: 464 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 5,904 | Highest Points: 5,904 | Total spins cast: 19
# Zero Points Percentage Game over -> Points: 2,050 | Highest Points: 2,050 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 10,350 | Highest Points: 10,350 | Total spins cast: 10
# Percentage Game over -> Points: 2,121 | Highest Points: 2,121 | Total spins cast: 9
# Ten Spins Percentage Game over -> Points: 20,938 | Highest Points: 21,150 | Total spins cast: 25
# Zero Points Percentage Game over -> Points: 11,882 | Highest Points: 11,882 | Total spins cast: 16
# Ten Spins Zero Points Percentage Game over -> Points: 3,510 | Highest Points: 3,510 | Total spins cast: 10
# Percentage Game over -> Points: 13,880 | Highest Points: 13,880 | Total spins cast: 15
# Ten Spins Percentage Game over -> Points: 6,915 | Highest Points: 6,915 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 700 | Highest Points: 700 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 1,720 | Highest Points: 1,720 | Total spins cast: 12
# Percentage Game over -> Points: 4,550 | Highest Points: 4,550 | Total spins cast: 8
# Ten Spins Percentage Game over -> Points: 8,252 | Highest Points: 8,252 | Total spins cast: 23
# Zero Points Percentage Game over -> Points: 3,050 | Highest Points: 3,050 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 4,045 | Highest Points: 9,425 | Total spins cast: 15
# Percentage Game over -> Points: 4,206 | Highest Points: 4,206 | Total spins cast: 18
# Ten Spins Percentage Game over -> Points: 30,728 | Highest Points: 30,728 | Total spins cast: 22
# Zero Points Percentage Game over -> Points: 4,163 | Highest Points: 4,163 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 604,087 | Highest Points: 1,207,874 | Total spins cast: 57
# Percentage Game over -> Points: 1,326 | Highest Points: 1,326 | Total spins cast: 9
# Ten Spins Percentage Game over -> Points: 26,746 | Highest Points: 26,746 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 10,552 | Highest Points: 10,552 | Total spins cast: 20
# Ten Spins Zero Points Percentage Game over -> Points: 6,616 | Highest Points: 6,616 | Total spins cast: 13
# Percentage Game over -> Points: 3,730 | Highest Points: 3,730 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 11,258 | Highest Points: 21,616 | Total spins cast: 28
# Zero Points Percentage Game over -> Points: 625 | Highest Points: 625 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 9,325 | Highest Points: 16,950 | Total spins cast: 23
# Percentage Game over -> Points: 1,450 | Highest Points: 1,450 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 6,875 | Highest Points: 6,875 | Total spins cast: 14
# Zero Points Percentage Game over -> Points: 8,250 | Highest Points: 8,250 | Total spins cast: 9
# Ten Spins Zero Points Percentage Game over -> Points: 0 | Highest Points: 13,872 | Total spins cast: 18
# Percentage Game over -> Points: 1,500 | Highest Points: 1,500 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 19,268 | Highest Points: 19,268 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 1,650 | Highest Points: 1,650 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 34,100 | Highest Points: 34,100 | Total spins cast: 34
# Percentage Game over -> Points: 30,166 | Highest Points: 30,166 | Total spins cast: 36
# Ten Spins Percentage Game over -> Points: 4,064 | Highest Points: 5,080 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 2,500 | Highest Points: 2,500 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 2,715 | Highest Points: 2,715 | Total spins cast: 12
# Percentage Game over -> Points: 634 | Highest Points: 792 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 2,225 | Highest Points: 2,225 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 3,350 | Highest Points: 3,350 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 18,792 | Highest Points: 18,792 | Total spins cast: 14
# Percentage Game over -> Points: 314 | Highest Points: 1,255 | Total spins cast: 9
# Ten Spins Percentage Game over -> Points: 26,532 | Highest Points: 26,532 | Total spins cast: 19
# Zero Points Percentage Game over -> Points: 1,300 | Highest Points: 1,300 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 7,210 | Highest Points: 7,210 | Total spins cast: 22
# Percentage Game over -> Points: 3,000 | Highest Points: 3,000 | Total spins cast: 9
# Ten Spins Percentage Game over -> Points: 13,916 | Highest Points: 13,916 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 0 | Highest Points: 0 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 4,515 | Highest Points: 4,515 | Total spins cast: 17
# Percentage Game over -> Points: 2,296 | Highest Points: 2,870 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 1,414 | Highest Points: 4,456 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 2,085 | Highest Points: 2,150 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 5,162 | Highest Points: 5,162 | Total spins cast: 17
# Percentage Game over -> Points: 2,100 | Highest Points: 2,100 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 2,418 | Highest Points: 2,418 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 675 | Highest Points: 750 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 21,070 | Highest Points: 23,078 | Total spins cast: 25
# Percentage Game over -> Points: 625 | Highest Points: 625 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 19,202 | Highest Points: 19,202 | Total spins cast: 24
# Zero Points Percentage Game over -> Points: 3,000 | Highest Points: 3,000 | Total spins cast: 15
# Ten Spins Zero Points Percentage Game over -> Points: 11,475 | Highest Points: 11,475 | Total spins cast: 19
# Percentage Game over -> Points: 236 | Highest Points: 650 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 3,449 | Highest Points: 3,449 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 5,260 | Highest Points: 5,260 | Total spins cast: 23
# Ten Spins Zero Points Percentage Game over -> Points: 7,740 | Highest Points: 7,740 | Total spins cast: 10
# Percentage Game over -> Points: 3,150 | Highest Points: 3,150 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 1,322 | Highest Points: 1,322 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 967 | Highest Points: 1,074 | Total spins cast: 12
# Ten Spins Zero Points Percentage Game over -> Points: 9,074 | Highest Points: 9,074 | Total spins cast: 27
# Percentage Game over -> Points: 972 | Highest Points: 972 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 2,844 | Highest Points: 2,844 | Total spins cast: 17
# Zero Points Percentage Game over -> Points: 2,300 | Highest Points: 2,300 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 4,350 | Highest Points: 4,350 | Total spins cast: 12
# Percentage Game over -> Points: 775 | Highest Points: 775 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 3,928 | Highest Points: 3,928 | Total spins cast: 14
# Zero Points Percentage Game over -> Points: 6,920 | Highest Points: 6,920 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 7,010 | Highest Points: 7,010 | Total spins cast: 18
# Percentage Game over -> Points: 5,730 | Highest Points: 5,730 | Total spins cast: 18
# Ten Spins Percentage Game over -> Points: 27,858 | Highest Points: 35,278 | Total spins cast: 38
# Zero Points Percentage Game over -> Points: 1,540 | Highest Points: 1,800 | Total spins cast: 9
# Ten Spins Zero Points Percentage Game over -> Points: 46,900 | Highest Points: 46,900 | Total spins cast: 13
# Percentage Game over -> Points: 3,950 | Highest Points: 3,950 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 300 | Highest Points: 3,650 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 617 | Highest Points: 617 | Total spins cast: 8
# Ten Spins Zero Points Percentage Game over -> Points: 2,674 | Highest Points: 2,674 | Total spins cast: 16
# Percentage Game over -> Points: 18,742 | Highest Points: 18,742 | Total spins cast: 14
# Ten Spins Percentage Game over -> Points: 6,600 | Highest Points: 6,600 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 4,650 | Highest Points: 4,650 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 4,100 | Highest Points: 4,100 | Total spins cast: 10
# Percentage Game over -> Points: 2,625 | Highest Points: 2,625 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 11,123 | Highest Points: 11,123 | Total spins cast: 20
# Zero Points Percentage Game over -> Points: 1,550 | Highest Points: 1,550 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 7,800 | Highest Points: 7,800 | Total spins cast: 20
# Percentage Game over -> Points: 298 | Highest Points: 300 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 3,272 | Highest Points: 3,360 | Total spins cast: 20
# Zero Points Percentage Game over -> Points: 1,110 | Highest Points: 1,110 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 1,958 | Highest Points: 1,958 | Total spins cast: 10
# Percentage Game over -> Points: 675 | Highest Points: 675 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 11,700 | Highest Points: 11,700 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 855 | Highest Points: 950 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 1,938 | Highest Points: 1,938 | Total spins cast: 10
# Percentage Game over -> Points: 1,648 | Highest Points: 1,648 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 25,418 | Highest Points: 25,418 | Total spins cast: 46
# Zero Points Percentage Game over -> Points: 5,915 | Highest Points: 5,915 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 15,520 | Highest Points: 19,400 | Total spins cast: 29
# Percentage Game over -> Points: 1,450 | Highest Points: 1,450 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 11,280 | Highest Points: 11,280 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 550 | Highest Points: 550 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 1,267 | Highest Points: 1,267 | Total spins cast: 10
# Percentage Game over -> Points: 1,475 | Highest Points: 1,475 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 7,188 | Highest Points: 7,188 | Total spins cast: 13
# Zero Points Percentage Game over -> Points: 892 | Highest Points: 892 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 4,762 | Highest Points: 16,850 | Total spins cast: 14
# Percentage Game over -> Points: 9,040 | Highest Points: 9,040 | Total spins cast: 15
# Ten Spins Percentage Game over -> Points: 3,639 | Highest Points: 3,924 | Total spins cast: 13
# Zero Points Percentage Game over -> Points: 7,000 | Highest Points: 7,000 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 1,202 | Highest Points: 1,202 | Total spins cast: 10
# Percentage Game over -> Points: 1,248 | Highest Points: 1,248 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 12,898 | Highest Points: 12,898 | Total spins cast: 16
# Zero Points Percentage Game over -> Points: 9,850 | Highest Points: 9,850 | Total spins cast: 21
# Ten Spins Zero Points Percentage Game over -> Points: 70,720 | Highest Points: 70,720 | Total spins cast: 22
# Percentage Game over -> Points: 1,480 | Highest Points: 1,480 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 1,492 | Highest Points: 1,725 | Total spins cast: 18
# Zero Points Percentage Game over -> Points: 1,176 | Highest Points: 1,176 | Total spins cast: 9
# Ten Spins Zero Points Percentage Game over -> Points: 5,745 | Highest Points: 7,660 | Total spins cast: 15
# Percentage Game over -> Points: 2,925 | Highest Points: 2,925 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 500 | Highest Points: 1,650 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 550 | Highest Points: 1,100 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 6,650 | Highest Points: 6,650 | Total spins cast: 14
# Percentage Game over -> Points: 1,348 | Highest Points: 1,348 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 3,678 | Highest Points: 3,678 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 6,136 | Highest Points: 6,818 | Total spins cast: 25
# Ten Spins Zero Points Percentage Game over -> Points: 2,165 | Highest Points: 2,165 | Total spins cast: 12
# Percentage Game over -> Points: 1,088 | Highest Points: 1,088 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 4,008 | Highest Points: 4,008 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 3,274 | Highest Points: 3,274 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 3,715 | Highest Points: 8,288 | Total spins cast: 26
# Percentage Game over -> Points: 248 | Highest Points: 619 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 12,679 | Highest Points: 12,679 | Total spins cast: 31
# Zero Points Percentage Game over -> Points: 2,500 | Highest Points: 2,500 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 10,780 | Highest Points: 10,780 | Total spins cast: 15
# Percentage Game over -> Points: 9,080 | Highest Points: 9,080 | Total spins cast: 15
# Ten Spins Percentage Game over -> Points: 2,504 | Highest Points: 2,504 | Total spins cast: 26
# Zero Points Percentage Game over -> Points: 1,066 | Highest Points: 1,066 | Total spins cast: 9
# Ten Spins Zero Points Percentage Game over -> Points: 4,387 | Highest Points: 4,387 | Total spins cast: 14
# Percentage Game over -> Points: 1,629 | Highest Points: 1,810 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 9,581 | Highest Points: 10,201 | Total spins cast: 24
# Zero Points Percentage Game over -> Points: 2,144 | Highest Points: 2,144 | Total spins cast: 18
# Ten Spins Zero Points Percentage Game over -> Points: 10,033 | Highest Points: 10,033 | Total spins cast: 10
# Percentage Game over -> Points: 5,115 | Highest Points: 6,200 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 98,340 | Highest Points: 98,340 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 700 | Highest Points: 700 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 3,465 | Highest Points: 3,850 | Total spins cast: 13
# Percentage Game over -> Points: 4,800 | Highest Points: 4,800 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 11,254 | Highest Points: 11,254 | Total spins cast: 21
# Zero Points Percentage Game over -> Points: 294 | Highest Points: 294 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 11,300 | Highest Points: 11,300 | Total spins cast: 12
# Percentage Game over -> Points: 2,480 | Highest Points: 2,480 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 6,377 | Highest Points: 16,250 | Total spins cast: 30
# Zero Points Percentage Game over -> Points: 1,091 | Highest Points: 1,091 | Total spins cast: 11
# Ten Spins Zero Points Percentage Game over -> Points: 22,131 | Highest Points: 24,590 | Total spins cast: 32
# Percentage Game over -> Points: 1,478 | Highest Points: 1,478 | Total spins cast: 8
# Ten Spins Percentage Game over -> Points: 1,935 | Highest Points: 3,070 | Total spins cast: 27
# Zero Points Percentage Game over -> Points: 1,270 | Highest Points: 1,270 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 8,048 | Highest Points: 8,048 | Total spins cast: 22
# Percentage Game over -> Points: 598 | Highest Points: 598 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 1,002,780 | Highest Points: 1,002,780 | Total spins cast: 35
# Zero Points Percentage Game over -> Points: 800 | Highest Points: 800 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 25,213 | Highest Points: 25,213 | Total spins cast: 28
# Percentage Game over -> Points: 1,100 | Highest Points: 2,200 | Total spins cast: 8
# Ten Spins Percentage Game over -> Points: 8,862 | Highest Points: 8,862 | Total spins cast: 13
# Zero Points Percentage Game over -> Points: 1,325 | Highest Points: 1,325 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 9,900 | Highest Points: 9,900 | Total spins cast: 15
# Percentage Game over -> Points: 123,804 | Highest Points: 123,804 | Total spins cast: 40
# Ten Spins Percentage Game over -> Points: 1,262 | Highest Points: 1,262 | Total spins cast: 13
# Zero Points Percentage Game over -> Points: 196,704 | Highest Points: 196,704 | Total spins cast: 17
# Ten Spins Zero Points Percentage Game over -> Points: 6,562 | Highest Points: 10,924 | Total spins cast: 29
# Percentage Game over -> Points: 5,690 | Highest Points: 5,690 | Total spins cast: 19
# Ten Spins Percentage Game over -> Points: 2,730 | Highest Points: 12,826 | Total spins cast: 24
# Zero Points Percentage Game over -> Points: 1,900 | Highest Points: 1,900 | Total spins cast: 8
# Ten Spins Zero Points Percentage Game over -> Points: 7,796 | Highest Points: 7,796 | Total spins cast: 19
# Percentage Game over -> Points: 2,500 | Highest Points: 2,500 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 4,300 | Highest Points: 4,300 | Total spins cast: 14
# Zero Points Percentage Game over -> Points: 6,250 | Highest Points: 6,250 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 725 | Highest Points: 11,000 | Total spins cast: 22
# Percentage Game over -> Points: 818 | Highest Points: 818 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 11,250 | Highest Points: 11,250 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 1,890 | Highest Points: 2,100 | Total spins cast: 11
# Ten Spins Zero Points Percentage Game over -> Points: 2,194 | Highest Points: 2,194 | Total spins cast: 15
# Percentage Game over -> Points: 1,880 | Highest Points: 1,880 | Total spins cast: 12
# Ten Spins Percentage Game over -> Points: 15,670 | Highest Points: 15,670 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 4,629 | Highest Points: 4,629 | Total spins cast: 22
# Ten Spins Zero Points Percentage Game over -> Points: 11,800 | Highest Points: 11,800 | Total spins cast: 13
# Percentage Game over -> Points: 3,849 | Highest Points: 3,849 | Total spins cast: 11
# Ten Spins Percentage Game over -> Points: 14,740 | Highest Points: 14,740 | Total spins cast: 17
# Zero Points Percentage Game over -> Points: 1,600 | Highest Points: 1,600 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 47,150 | Highest Points: 47,150 | Total spins cast: 36
# Percentage Game over -> Points: 3,152 | Highest Points: 3,152 | Total spins cast: 10
# Ten Spins Percentage Game over -> Points: 25,126 | Highest Points: 25,126 | Total spins cast: 30
# Zero Points Percentage Game over -> Points: 0 | Highest Points: 0 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 20,211 | Highest Points: 20,211 | Total spins cast: 35
# Percentage Game over -> Points: 15,220 | Highest Points: 15,220 | Total spins cast: 8
# Ten Spins Percentage Game over -> Points: 1,144 | Highest Points: 1,888 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 1,130 | Highest Points: 1,130 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 3,810 | Highest Points: 3,810 | Total spins cast: 13
# Percentage Game over -> Points: 981 | Highest Points: 981 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 5,986 | Highest Points: 5,986 | Total spins cast: 13
# Zero Points Percentage Game over -> Points: 3,288 | Highest Points: 3,288 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 45,558 | Highest Points: 60,610 | Total spins cast: 18
# Percentage Game over -> Points: 24,244 | Highest Points: 24,244 | Total spins cast: 33
# Ten Spins Percentage Game over -> Points: 7,048 | Highest Points: 7,048 | Total spins cast: 19
# Zero Points Percentage Game over -> Points: 900 | Highest Points: 900 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 2,960 | Highest Points: 2,960 | Total spins cast: 10
# Percentage Game over -> Points: 12,400 | Highest Points: 12,400 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 35,284 | Highest Points: 35,284 | Total spins cast: 22
# Zero Points Percentage Game over -> Points: 1,860 | Highest Points: 1,860 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 2,778 | Highest Points: 3,038 | Total spins cast: 14
# Percentage Game over -> Points: 675 | Highest Points: 2,700 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 5,842 | Highest Points: 5,842 | Total spins cast: 21
# Zero Points Percentage Game over -> Points: 4,950 | Highest Points: 4,950 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 5,240 | Highest Points: 5,240 | Total spins cast: 29
# Percentage Game over -> Points: 1,250 | Highest Points: 1,250 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 2,448 | Highest Points: 6,530 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 2,325 | Highest Points: 2,325 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 2,712 | Highest Points: 2,765 | Total spins cast: 12
# Percentage Game over -> Points: 1,350 | Highest Points: 1,350 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 2,188 | Highest Points: 2,431 | Total spins cast: 17
# Zero Points Percentage Game over -> Points: 1,050 | Highest Points: 1,050 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 2,900 | Highest Points: 2,900 | Total spins cast: 10
# Percentage Game over -> Points: 2,438 | Highest Points: 2,438 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 21,802 | Highest Points: 21,802 | Total spins cast: 24
# Zero Points Percentage Game over -> Points: 2,200 | Highest Points: 2,200 | Total spins cast: 8
# Ten Spins Zero Points Percentage Game over -> Points: 10,550 | Highest Points: 10,550 | Total spins cast: 16
# Percentage Game over -> Points: 1,412 | Highest Points: 1,412 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 7,974 | Highest Points: 7,974 | Total spins cast: 14
# Zero Points Percentage Game over -> Points: 750 | Highest Points: 750 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 70,072 | Highest Points: 70,072 | Total spins cast: 51
# Percentage Game over -> Points: 4,100 | Highest Points: 4,100 | Total spins cast: 13
# Ten Spins Percentage Game over -> Points: 3,254 | Highest Points: 3,254 | Total spins cast: 13
# Zero Points Percentage Game over -> Points: 1,750 | Highest Points: 1,750 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 5,588 | Highest Points: 11,176 | Total spins cast: 16
# Percentage Game over -> Points: 3,322 | Highest Points: 3,322 | Total spins cast: 12
# Ten Spins Percentage Game over -> Points: 3,922 | Highest Points: 3,922 | Total spins cast: 23
# Zero Points Percentage Game over -> Points: 5,500 | Highest Points: 5,500 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 4,100 | Highest Points: 5,900 | Total spins cast: 17
# Percentage Game over -> Points: 3,696 | Highest Points: 3,696 | Total spins cast: 14
# Ten Spins Percentage Game over -> Points: 30,348 | Highest Points: 30,348 | Total spins cast: 15
# Zero Points Percentage Game over -> Points: 4,800 | Highest Points: 4,800 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 26,412 | Highest Points: 26,412 | Total spins cast: 19
# Percentage Game over -> Points: 1,996 | Highest Points: 2,662 | Total spins cast: 23
# Ten Spins Percentage Game over -> Points: 11,400 | Highest Points: 11,400 | Total spins cast: 21
# Zero Points Percentage Game over -> Points: 3,867 | Highest Points: 7,468 | Total spins cast: 39
# Ten Spins Zero Points Percentage Game over -> Points: 50,636 | Highest Points: 50,636 | Total spins cast: 21
# Percentage Game over -> Points: 1,150 | Highest Points: 1,150 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 2,230 | Highest Points: 2,230 | Total spins cast: 12
# Zero Points Percentage Game over -> Points: 2,458 | Highest Points: 2,620 | Total spins cast: 14
# Ten Spins Zero Points Percentage Game over -> Points: 41,936 | Highest Points: 41,936 | Total spins cast: 37
# Percentage Game over -> Points: 5,195 | Highest Points: 5,195 | Total spins cast: 10
# Ten Spins Percentage Game over -> Points: 19,414 | Highest Points: 25,886 | Total spins cast: 37
# Zero Points Percentage Game over -> Points: 0 | Highest Points: 0 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 2,220 | Highest Points: 2,600 | Total spins cast: 10
# Percentage Game over -> Points: 850 | Highest Points: 850 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 3,462 | Highest Points: 3,462 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 14,580 | Highest Points: 14,580 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 6,870 | Highest Points: 6,870 | Total spins cast: 15
# Percentage Game over -> Points: 4,375 | Highest Points: 4,375 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 33,750 | Highest Points: 35,500 | Total spins cast: 35
# Zero Points Percentage Game over -> Points: 250 | Highest Points: 250 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 2,376 | Highest Points: 2,376 | Total spins cast: 13
# Percentage Game over -> Points: 1,110 | Highest Points: 1,110 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 1,384 | Highest Points: 1,384 | Total spins cast: 13
# Zero Points Percentage Game over -> Points: 4,351 | Highest Points: 4,351 | Total spins cast: 15
# Ten Spins Zero Points Percentage Game over -> Points: 3,170 | Highest Points: 7,924 | Total spins cast: 14
# Percentage Game over -> Points: 9,640 | Highest Points: 9,640 | Total spins cast: 17
# Ten Spins Percentage Game over -> Points: 2,418 | Highest Points: 2,418 | Total spins cast: 16
# Zero Points Percentage Game over -> Points: 2,351 | Highest Points: 2,950 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 3,833 | Highest Points: 5,323 | Total spins cast: 21
# Percentage Game over -> Points: 8,825 | Highest Points: 8,825 | Total spins cast: 15
# Ten Spins Percentage Game over -> Points: 18,752 | Highest Points: 18,752 | Total spins cast: 18
# Zero Points Percentage Game over -> Points: 2,600 | Highest Points: 2,600 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 6,327 | Highest Points: 6,327 | Total spins cast: 28
# Percentage Game over -> Points: 2,962 | Highest Points: 2,962 | Total spins cast: 8
# Ten Spins Percentage Game over -> Points: 1,863 | Highest Points: 1,863 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 1,900 | Highest Points: 1,900 | Total spins cast: 10
# Ten Spins Zero Points Percentage Game over -> Points: 10,878 | Highest Points: 10,878 | Total spins cast: 18
# Percentage Game over -> Points: 10,540 | Highest Points: 10,540 | Total spins cast: 13
# Ten Spins Percentage Game over -> Points: 2,960 | Highest Points: 2,960 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 1,062 | Highest Points: 1,062 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 28,250 | Highest Points: 28,250 | Total spins cast: 13
# Percentage Game over -> Points: 3,750 | Highest Points: 3,750 | Total spins cast: 7
# Ten Spins Percentage Game over -> Points: 11,270 | Highest Points: 11,270 | Total spins cast: 13
# Zero Points Percentage Game over -> Points: 0 | Highest Points: 1,610 | Total spins cast: 9
# Ten Spins Zero Points Percentage Game over -> Points: 4,002 | Highest Points: 4,002 | Total spins cast: 17
# Percentage Game over -> Points: 1,950 | Highest Points: 1,950 | Total spins cast: 8
# Ten Spins Percentage Game over -> Points: 5,458 | Highest Points: 5,458 | Total spins cast: 10
# Zero Points Percentage Game over -> Points: 2,880 | Highest Points: 2,880 | Total spins cast: 5
# Ten Spins Zero Points Percentage Game over -> Points: 6,262 | Highest Points: 6,262 | Total spins cast: 10
# Percentage Game over -> Points: 1,650 | Highest Points: 1,650 | Total spins cast: 5
# Ten Spins Percentage Game over -> Points: 6,181 | Highest Points: 6,181 | Total spins cast: 17
# Zero Points Percentage Game over -> Points: 1,120 | Highest Points: 1,120 | Total spins cast: 7
# Ten Spins Zero Points Percentage Game over -> Points: 321,142 | Highest Points: 321,142 | Total spins cast: 33
